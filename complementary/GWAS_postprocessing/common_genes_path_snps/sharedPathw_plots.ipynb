# %% [markdown]
# # Shared Pathw phenotypes

# %% [markdown]
# ###### Latest modif 06/12/2022

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import csv
import seaborn as sns
from datetime import datetime
import os
import glob
#from pySankey.sankey import sankey
import imageio
from pandas.plotting import parallel_coordinates

DATE = datetime.now().strftime("%Y-%m-%d")

# %%
p_value_min = 5.8  # -math.log10(0.05/len(x))

directory_path='/NVME/decrypted/scratch/multitrait/UK_BIOBANK_PREPRINT/gwas/2022_11_23_covar_fix/'
save_dir= '/NVME/decrypted/scratch/multitrait/UK_BIOBANK_PREPRINT/figures/'
type_phenots='main' # supplementary, main
if type_phenots=='main':
    ##### MAIN PHENOTYPES
    MAIN_LABELS='mean_angle_taa,mean_angle_tva,tau1_vein,tau1_artery,ratio_AV_DF,eq_CRAE,ratio_CRAE_CRVE,D_A_std,D_V_std,eq_CRVE,ratio_VD,VD_orig_artery,bifurcations,VD_orig_vein,medianDiameter_artery,medianDiameter_vein,ratio_AV_medianDiameter'
    MAIN_NAMES='A temporal angle,V temporal angle,V tortuosity,A tortuosity,ratio tortuosity,A central retinal eq,ratio central retinal eq,A std diameter,V std diameter,V central retinal eq,ratio vascular density,A vascular density,bifurcations,V vascular density,A median diameter,V median diameter,ratio median diameter'
   
    all_files = list(MAIN_LABELS.split(","))
    all_files_new = list(MAIN_NAMES.split(","))
    #df_i=pd.read_csv('/NVME/decrypted/scratch/multitrait/UK_BIOBANK_PREPRINT/figures/intersections_all_main_vZekavat.csv')

elif type_phenots=='supplementary':
    #### SUPPLEMENTARY PHENOTYPES
    SUPPLEMENTARY_LABELS='tau1_all,tau1_artery,tau1_vein,ratio_AV_DF,tau2_all,tau2_artery,tau2_vein,tau4_all,tau4_artery,tau4_vein,D_std,D_A_std,D_V_std,D_CVMe,D_CVMe_A,D_CVMe_V,sd_mean_size,N_median_main_arteries,N_median_main_veins,arcLength_artery,arcLength_vein,bifurcations,VD_orig_all,VD_orig_artery,VD_orig_vein,ratio_VD,FD_all,FD_artery,FD_vein,mean_angle_taa,mean_angle_tva,eq_CRAE,eq_CRVE,median_CRAE,median_CRVE,CRAE,CRVE,ratio_CRAE_CRVE,ratio_median_CRAE_CRVE,ratio_standard_CRE,medianDiameter_all,medianDiameter_artery,medianDiameter_vein,ratio_AV_medianDiameter'
    SUPPLEMENTARY_NAMES='tortuosity,A tortuosity,V tortuosity,ratio tortuosity,tortuosity2,A tortuosity2,V tortuosity2,tortuosity3,A tortuosity3,V tortuosity3,std diameter,A std diameter,V std diameter,CVMe diameter,A CVMe diameter,V CVMe diameter,std norm diameter,A num main,V num main,A arc length,V arc length,bifurcations,vascular density,A vascular density,V vascular density,ratio vascular density,fractal dimension,A fractal dimension,V fractal dimension,A temporal angle,V temporal angle,A central retinal eq,V central retinal eq,A main diameter,V main diameter,A central retinal eq2,V central retinal eq2,ratio central retinal eq,ratio main diameter,ratio central retinal eq2,median diameter,A median diameter,V median diameter,ratio median diameter'
    all_files = list(SUPPLEMENTARY_LABELS.split(","))
    all_files_new = list(SUPPLEMENTARY_NAMES.split(","))
    #df_i=pd.read_csv('/NVME/decrypted/scratch/multitrait/UK_BIOBANK_PREPRINT/figures/intersections_all_suplementary_vZekavat.csv')

# %%
mapping_labels = dict(zip(all_files, all_files_new))
mapping_order = dict(zip(all_files_new, list(range(len(all_files_new)))))

# %%
l_path_shared_all= []
appended_data = []

    
for file in all_files:
    # Read csvs
    df = pd.read_csv(directory_path+file+'__pathway_scores.txt', delimiter=' ', names =['pathway', 'one', 'second', 'p']) #, index_col=None, header=0)
    df['file_col']=file

    # From p to -log10(p)
    df['-log10(p)'] = -np.log10(df['p'])
    y = df[df['-log10(p)'] >= p_value_min]
    df_significant = y.sort_values('-log10(p)', ascending=False)
    df_significant['pheno']=file
    appended_data.append(df_significant)
    phenotype_path=df_significant['pathway'].to_list()
    print(file, len(phenotype_path), '\n')
    #print(file, len(phenotype_path), phenotype_path, '\n')
    #print(df_significant)
    
appended_data = pd.concat(appended_data)
# Out:
# mean_angle_taa 3
#
# mean_angle_tva 2
#
# tau1_vein 11
#
# tau1_artery 42
#
# ratio_AV_DF 18
#
# eq_CRAE 0
#
# ratio_CRAE_CRVE 1
#
# D_A_std 3
#
# D_V_std 7
#
# eq_CRVE 2
#
# ratio_VD 4
#
# VD_orig_artery 1
#
# bifurcations 2
#
# VD_orig_vein 6
#
# medianDiameter_artery 0
#
# medianDiameter_vein 0
#
# ratio_AV_medianDiameter 1

# %%
appended_data
appended_data['pathway'].value_counts().index
list_path=list(appended_data['pathway'].value_counts().head(30).index)
list_path
df_reduc = appended_data[appended_data['pathway'].isin(list_path)]
df_reduc
df_reduc['file_col'] = df_reduc['file_col'].map(mapping_labels)
df_reduc['order']= df_reduc['file_col'].map(mapping_order)
df_reduc.sort_values(by='order', ascending=False, inplace=True)
# Out:
# /tmp/ipykernel_34238/263442324.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduc['file_col'] = df_reduc['file_col'].map(mapping_labels)
# /tmp/ipykernel_34238/263442324.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduc['order']= df_reduc['file_col'].map(mapping_order)
# /tmp/ipykernel_34238/263442324.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduc.sort_values(by='order', ascending=False, inplace=True)

# %%
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['axes.titlesize'] = 12
if type_phenots=='main':
    plt.figure(figsize=(13, 4))
    name_save='main_pathway_phenotypes_scatterplots_25_11_2022.png'
elif type_phenots=='supplementary':
    plt.figure(figsize=(15, 12))
    name_save='sup_pathway_phenotypes_scatterplots_25_11_2022.png'
#plt.xlabel('Genes') 
#plt.ylabel('Phenotypes')

plt.rcParams['font.size'] = '12'
#plt.scatter(df_reduc['pathway'], df_reduc['file_col'], cmap='turbo', c=df_reduc['-log10(p)'], s=1.5*df_reduc['-log10(p)'])
plt.scatter(df_reduc['pathway'], df_reduc['file_col'], s=1.25*df_reduc['-log10(p)'])
#cbar= plt.colorbar(fraction=0.1)
#cbar.set_label('-log(p)')
plt.grid(color='gray', linestyle='-', linewidth=0.1)
#plt.stem(df_reduc['pathway'], df_reduc['file_col'],  basefmt = " ") #markerfmt='.',
plt.xticks(df_reduc['pathway'], rotation=45, ha='right')
# Out:
# ([<matplotlib.axis.XTick at 0x7ff35b69fa30>,
#   <matplotlib.axis.XTick at 0x7ff35b69f880>,
#   <matplotlib.axis.XTick at 0x7ff35b68a340>,
#   <matplotlib.axis.XTick at 0x7ff35b651580>,
#   <matplotlib.axis.XTick at 0x7ff35b651cd0>,
#   <matplotlib.axis.XTick at 0x7ff35b651a90>,
#   <matplotlib.axis.XTick at 0x7ff35b65b580>,
#   <matplotlib.axis.XTick at 0x7ff35b65bcd0>,
#   <matplotlib.axis.XTick at 0x7ff35b661460>,
#   <matplotlib.axis.XTick at 0x7ff35b661bb0>,
#   <matplotlib.axis.XTick at 0x7ff35b667340>,
#   <matplotlib.axis.XTick at 0x7ff35b667a90>,
#   <matplotlib.axis.XTick at 0x7ff35b661550>,
#   <matplotlib.axis.XTick at 0x7ff35b667d90>,
#   <matplotlib.axis.XTick at 0x7ff35b5ef070>,
#   <matplotlib.axis.XTick at 0x7ff35b5ef6a0>,
#   <matplotlib.axis.XTick at 0x7ff35b5efdf0>,
#   <matplotlib.axis.XTick at 0x7ff35b5f5580>,
#   <matplotlib.axis.XTick at 0x7ff35b5efe50>,
#   <matplotlib.axis.XTick at 0x7ff35b667430>,
#   <matplotlib.axis.XTick at 0x7ff35b5f5df0>,
#   <matplotlib.axis.XTick at 0x7ff35b5fd190>,
#   <matplotlib.axis.XTick at 0x7ff35b5fd8e0>,
#   <matplotlib.axis.XTick at 0x7ff35b602070>,
#   <matplotlib.axis.XTick at 0x7ff35b6027c0>,
#   <matplotlib.axis.XTick at 0x7ff35b5fd910>,
#   <matplotlib.axis.XTick at 0x7ff35b65bd90>,
#   <matplotlib.axis.XTick at 0x7ff35b6022e0>,
#   <matplotlib.axis.XTick at 0x7ff35b60c460>,
#   <matplotlib.axis.XTick at 0x7ff35b60cbb0>,
#   <matplotlib.axis.XTick at 0x7ff35b611340>,
#   <matplotlib.axis.XTick at 0x7ff35b611a90>,
#   <matplotlib.axis.XTick at 0x7ff35b60c940>,
#   <matplotlib.axis.XTick at 0x7ff35b65bca0>,
#   <matplotlib.axis.XTick at 0x7ff35b6112b0>,
#   <matplotlib.axis.XTick at 0x7ff35b619610>,
#   <matplotlib.axis.XTick at 0x7ff35b619d60>,
#   <matplotlib.axis.XTick at 0x7ff35b61e4f0>,
#   <matplotlib.axis.XTick at 0x7ff35b61ec40>,
#   <matplotlib.axis.XTick at 0x7ff35b61e520>,
#   <matplotlib.axis.XTick at 0x7ff35b6110d0>,
#   <matplotlib.axis.XTick at 0x7ff35b628070>,
#   <matplotlib.axis.XTick at 0x7ff35b6287c0>,
#   <matplotlib.axis.XTick at 0x7ff35b5ac070>,
#   <matplotlib.axis.XTick at 0x7ff35b5ac6a0>,
#   <matplotlib.axis.XTick at 0x7ff35b628f70>,
#   <matplotlib.axis.XTick at 0x7ff35b611100>,
#   <matplotlib.axis.XTick at 0x7ff35b5acf40>,
#   <matplotlib.axis.XTick at 0x7ff35b5b52b0>,
#   <matplotlib.axis.XTick at 0x7ff35b5b5a00>,
#   <matplotlib.axis.XTick at 0x7ff35b5bb190>,
#   <matplotlib.axis.XTick at 0x7ff35b5bb8e0>,
#   <matplotlib.axis.XTick at 0x7ff35b5b5a60>,
#   <matplotlib.axis.XTick at 0x7ff35b61e550>,
#   <matplotlib.axis.XTick at 0x7ff35b5bb430>,
#   <matplotlib.axis.XTick at 0x7ff35b5c6580>,
#   <matplotlib.axis.XTick at 0x7ff35b5c6cd0>,
#   <matplotlib.axis.XTick at 0x7ff35b5c9460>,
#   <matplotlib.axis.XTick at 0x7ff35b5c9bb0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
l_aux = []

for file in all_files:
    #print('file', file)
    # Read csvs
    df = pd.read_csv(directory_path+file+'__pathway_scores.txt', delimiter=' ', names =['pathway', 'one', 'second', 'p']) #, index_col=None, header=0)

    df['file_col']=file
    l_aux.append(df)

# Concat all the csvs
df_concat = pd.concat(l_aux)

# From p to -log10(p)
df_concat['-log10(p)'] = -np.log10(df_concat['p'])
y = df_concat[df_concat['-log10(p)'] >= p_value_min]
df_significant = y.sort_values('-log10(p)', ascending=False)
#print(df_significant.head(5))
#df_significant.to_csv(save_results + csv_name_all + '.csv')
df_count=df_significant['pathway'].value_counts().to_frame()
df_count['ratio_N_pheno']=df_significant['pathway'].value_counts().to_frame()/len(all_files)
#df_count.to_csv(save_results + csv_name_count + '.csv')

## Save the number of significant genes per phenotype
df_guardar = pd.DataFrame(df_significant.groupby(by=['file_col'])['pathway'].apply(list))
df_guardar2 = pd.DataFrame(df_significant.groupby(by=['file_col'])['pathway'].count())
df_guardar_final=df_guardar.merge(df_guardar2, how='inner', on='file_col')
#df_guardar_final.to_csv(save_results + csv_name_diagonal +'.csv')
df_save_shapes=pd.DataFrame([])
df_save_intersections=pd.DataFrame([])


i=0
for file in all_files:
    i=i+1
    genes=df_significant[df_significant['file_col']==file]['pathway']#.to_list()
    genes=genes.to_list()
    l_aux2 = []
    l_aux3 = []

    for j in range(len(all_files)):#-i):#-file: #Error
        other_file=all_files[j]
        df_intersection=df_significant[(df_significant['file_col']==other_file)&(df_significant['pathway'].isin(genes))]
        # To save the intersection len
        save_shapes=df_intersection.shape[0]
        l_aux3.append(save_shapes)

        # To save the names of the genes in the intersection
        l_aux2.append(df_intersection['pathway'].to_list())# {'index1': value1, 'index2':value2,...}, ignore_index=True)#.to_list())
        #print('antes', df_intersection['gen'].to_list(), 'despues')
        #print(df_intersection['gen'].values())

    # To save the intersection len
    df = pd.DataFrame({file:l_aux3})
    df_save_shapes = pd.concat([df_save_shapes, df], axis=1)

    # To save the names of the genes in the intersection
    df2 = pd.DataFrame({file:l_aux2})
    df_save_intersections = pd.concat([df_save_intersections, df2], axis=1)
    #print(df_save_intersections[1])

# To save the intersection len  
df_save_shapes = df_save_shapes.set_axis(df_save_shapes.columns, axis='index')

#df_save_shapes.to_csv(save_results + csv_name +'.csv')

# To save the names of the genes in the intersection
df_save_intersections = df_save_intersections.set_axis(df_save_intersections.columns, axis='index')
#df_save_intersections.to_csv(save_results + csv_genes_name + '.csv')

df_save_intersections.rename(columns=dict(zip(all_files, all_files_new)), inplace=True)
df_save_intersections.rename(index=dict(zip(all_files, all_files_new)), inplace=True)
df_save_shapes.rename(columns=dict(zip(all_files, all_files_new)), inplace=True)
df_save_shapes.rename(index=dict(zip(all_files, all_files_new)), inplace=True)
#return df_count, df_guardar_final, df_save_shapes, df_save_intersections

# %%
df_save_intersections
# Out:
#                                                            A temporal angle  \
# A temporal angle          [GO_NEURON_DIFFERENTIATION, GO_SENSORY_SYSTEM_...
# V temporal angle                                                         []
# V tortuosity                                                             []
# A tortuosity                                                             []
# ratio tortuosity                                                         []
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter                                                           []
# V std diameter                                                           []
# V central retinal eq                                                     []
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                                                            V temporal angle  \
# A temporal angle                                                         []
# V temporal angle          [chr8q23, GO_POSITIVE_REGULATION_OF_BROWN_FAT_...
# V tortuosity                                                             []
# A tortuosity                                                             []
# ratio tortuosity                                                         []
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter                                                           []
# V std diameter                                                           []
# V central retinal eq                                                     []
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                                                                V tortuosity  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity              [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# A tortuosity              [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# ratio tortuosity          [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter                                                           []
# V std diameter                                                           []
# V central retinal eq                                                     []
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                                                                A tortuosity  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity              [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# A tortuosity              [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# ratio tortuosity          [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter                                                           []
# V std diameter            [MANNO_MIDBRAIN_NEUROTYPES_HENDO, GAO_LARGE_IN...
# V central retinal eq            [GAO_LARGE_INTESTINE_ADULT_CJ_IMMUNE_CELLS]
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                        [GO_RESPONSE_TO_GROWTH_FACTOR]
#
#                                                            ratio tortuosity  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity              [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# A tortuosity              [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# ratio tortuosity          [FAN_EMBRYONIC_CTX_BIG_GROUPS_BRAIN_ENDOTHELIA...
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter                                                           []
# V std diameter            [MANNO_MIDBRAIN_NEUROTYPES_HENDO, GAO_LARGE_IN...
# V central retinal eq            [GAO_LARGE_INTESTINE_ADULT_CJ_IMMUNE_CELLS]
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                          A central retinal eq ratio central retinal eq  \
# A temporal angle                           []                       []
# V temporal angle                           []                       []
# V tortuosity                               []                       []
# A tortuosity                               []                       []
# ratio tortuosity                           []                       []
# A central retinal eq                       []                       []
# ratio central retinal eq                   []                [chr8p23]
# A std diameter                             []                       []
# V std diameter                             []                [chr8p23]
# V central retinal eq                       []                [chr8p23]
# ratio vascular density                     []                       []
# A vascular density                         []                       []
# bifurcations                               []                       []
# V vascular density                         []                       []
# A median diameter                          []                       []
# V median diameter                          []                       []
# ratio median diameter                      []                       []
#
#                                                              A std diameter  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity                                                             []
# A tortuosity                                                             []
# ratio tortuosity                                                         []
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter            [chr6p22, HP_PHOTOPHOBIA, HP_ABNORMAL_RETINAL_...
# V std diameter                             [HP_ABNORMAL_RETINAL_MORPHOLOGY]
# V central retinal eq                                                     []
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                                                              V std diameter  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity                                                             []
# A tortuosity              [MANNO_MIDBRAIN_NEUROTYPES_HENDO, GAO_LARGE_IN...
# ratio tortuosity          [MANNO_MIDBRAIN_NEUROTYPES_HENDO, GAO_LARGE_IN...
# A central retinal eq                                                     []
# ratio central retinal eq                                          [chr8p23]
# A std diameter                             [HP_ABNORMAL_RETINAL_MORPHOLOGY]
# V std diameter            [CUI_DEVELOPING_HEART_C4_ENDOTHELIAL_CELL, MAN...
# V central retinal eq      [chr8p23, GAO_LARGE_INTESTINE_ADULT_CJ_IMMUNE_...
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                                                        V central retinal eq  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity                                                             []
# A tortuosity                    [GAO_LARGE_INTESTINE_ADULT_CJ_IMMUNE_CELLS]
# ratio tortuosity                [GAO_LARGE_INTESTINE_ADULT_CJ_IMMUNE_CELLS]
# A central retinal eq                                                     []
# ratio central retinal eq                                          [chr8p23]
# A std diameter                                                           []
# V std diameter            [chr8p23, GAO_LARGE_INTESTINE_ADULT_CJ_IMMUNE_...
# V central retinal eq      [chr8p23, GAO_LARGE_INTESTINE_ADULT_CJ_IMMUNE_...
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                                                      ratio vascular density  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity                                                             []
# A tortuosity                                                             []
# ratio tortuosity                                                         []
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter                                                           []
# V std diameter                                                           []
# V central retinal eq                                                     []
# ratio vascular density    [GO_POSITIVE_REGULATION_OF_NUCLEOBASE_CONTAINI...
# A vascular density                                                       []
# bifurcations                                                             []
# V vascular density                                                       []
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                              A vascular density  \
# A temporal angle                             []
# V temporal angle                             []
# V tortuosity                                 []
# A tortuosity                                 []
# ratio tortuosity                             []
# A central retinal eq                         []
# ratio central retinal eq                     []
# A std diameter                               []
# V std diameter                               []
# V central retinal eq                         []
# ratio vascular density                       []
# A vascular density        [HP_OVARIAN_NEOPLASM]
# bifurcations                                 []
# V vascular density                           []
# A median diameter                            []
# V median diameter                            []
# ratio median diameter                        []
#
#                                                                bifurcations  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity                                                             []
# A tortuosity                                                             []
# ratio tortuosity                                                         []
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter                                                           []
# V std diameter                                                           []
# V central retinal eq                                                     []
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations              [HP_ABNORMAL_ANTERIOR_EYE_SEGMENT_MORPHOLOGY, ...
# V vascular density            [HP_ABNORMAL_ANTERIOR_EYE_SEGMENT_MORPHOLOGY]
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                                                          V vascular density  \
# A temporal angle                                                         []
# V temporal angle                                                         []
# V tortuosity                                                             []
# A tortuosity                                                             []
# ratio tortuosity                                                         []
# A central retinal eq                                                     []
# ratio central retinal eq                                                 []
# A std diameter                                                           []
# V std diameter                                                           []
# V central retinal eq                                                     []
# ratio vascular density                                                   []
# A vascular density                                                       []
# bifurcations                  [HP_ABNORMAL_ANTERIOR_EYE_SEGMENT_MORPHOLOGY]
# V vascular density        [HP_ABNORMAL_UVEA_MORPHOLOGY, HU_FETAL_RETINA_...
# A median diameter                                                        []
# V median diameter                                                        []
# ratio median diameter                                                    []
#
#                          A median diameter V median diameter  \
# A temporal angle                        []                []
# V temporal angle                        []                []
# V tortuosity                            []                []
# A tortuosity                            []                []
# ratio tortuosity                        []                []
# A central retinal eq                    []                []
# ratio central retinal eq                []                []
# A std diameter                          []                []
# V std diameter                          []                []
# V central retinal eq                    []                []
# ratio vascular density                  []                []
# A vascular density                      []                []
# bifurcations                            []                []
# V vascular density                      []                []
# A median diameter                       []                []
# V median diameter                       []                []
# ratio median diameter                   []                []
#
#                                    ratio median diameter
# A temporal angle                                      []
# V temporal angle                                      []
# V tortuosity                                          []
# A tortuosity              [GO_RESPONSE_TO_GROWTH_FACTOR]
# ratio tortuosity                                      []
# A central retinal eq                                  []
# ratio central retinal eq                              []
# A std diameter                                        []
# V std diameter                                        []
# V central retinal eq                                  []
# ratio vascular density                                []
# A vascular density                                    []
# bifurcations                                          []
# V vascular density                                    []
# A median diameter                                     []
# V median diameter                                     []
# ratio median diameter     [GO_RESPONSE_TO_GROWTH_FACTOR]

# %%
np_upper = np.triu(df_save_shapes, k=+1)
#df = df1.fillna(df2)

mask = np.zeros_like(np_upper)
mask[np.triu_indices_from(mask, k=+1)] = True

sns.heatmap(df_save_shapes, annot=df_save_shapes, fmt='',  cmap='Blues', mask=mask, cbar_kws={'label': 'Number of significant pathways'})
# Out:
# <AxesSubplot:>

# %%
np_upper = np.tril(df_save_shapes, k=-1)
#df = df1.fillna(df2)

mask = np.zeros_like(np_upper)
mask[np.tril_indices_from(mask, k=-1)] = True

sns.heatmap(df_save_shapes, annot=df_save_shapes, fmt='',  cmap='Blues', mask=mask, cbar_kws={'label': 'Number of significant pathways'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Note -> all_GWAScatalog contain all the traits (not yet filtered by etnicity)

# %%
#f_genes_count[df_genes_count['Unnamed: 0']=='CTD-2008P7.9']

# %%
df_gene_disease = pd.read_csv(save_dir + '2022_08_17_all_GWAScatalog_ventile4.csv')
df_gene_disease

#os.chdir(save_dir)
#for file_name in glob.glob("*GWAScatalog_ventile4.csv"):
    #print(file_name)
    #df_gene_disease = pd.read_csv(save_dir + file_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 df_gene_disease = pd.read_csv(save_dir + '2022_08_17_all_GWAScatalog_ventile4.csv')
#       2 df_gene_disease
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas-1.4.2-py3.9-linux-x86_64.egg/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas-1.4.2-py3.9-linux-x86_64.egg/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas-1.4.2-py3.9-linux-x86_64.egg/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas-1.4.2-py3.9-linux-x86_64.egg/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas-1.4.2-py3.9-linux-x86_64.egg/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas-1.4.2-py3.9-linux-x86_64.egg/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/NVME/decrypted/scratch/multitrait/UK_BIOBANK_PREPRINT/figures/2022_08_17_all_GWAScatalog_ventile4.csv'

# %% [markdown]
# ### - Filter by etnicity

# %%
df_gene_disease_filtered = df_gene_disease[df_gene_disease["INITIAL SAMPLE SIZE"].str.contains("European" or "British")]
print('Len before and after filter by etnicity: ', len(df_gene_disease), len(df_gene_disease_filtered))
df_gene_disease_filtered
# Out:
# Len before and after filter by etnicity:  544 447
#      Unnamed: 0                                       MAPPED_TRAIT    gene  \
# 1             1                                    Ischemic stroke   LRCH1
# 2             2                                    Ischemic stroke   LRCH1
# 3             3  Ischemic stroke, venous thromboembolism, strok...   PROCR
# 4             4  HDL cholesterol change measurement, response t...  TGFBR3
# 5             5             refractive error, age at onset, Myopia   PDE3A
# ..          ...                                                ...     ...
# 539         539                            vitamin B12 measurement    FUT2
# 540         540                            vitamin B12 measurement    FUT2
# 541         541                            vitamin B12 measurement    FUT2
# 542         542                            vitamin B12 measurement    FUT2
# 543         543                            vitamin B12 measurement    FUT2
#
#                                    INITIAL SAMPLE SIZE  \
# 1    34,217 European ancestry cases, 406,111 Europe...
# 2    34,217 European ancestry cases, 406,111 Europe...
# 3    6,135 European ancestry cases, 252,827 Europea...
# 4    781 European ancestry individuals, 138 African...
# 5    145,366 European ancestry individuals, 2,610 E...
# ..                                                 ...
# 539  1,725 European ancestry cases, 258 African anc...
# 540  1,725 European ancestry cases, 258 African anc...
# 541  1,725 European ancestry cases, 258 African anc...
# 542  1,725 European ancestry cases, 258 African anc...
# 543  1,725 European ancestry cases, 258 African anc...
#
#                        Trait
# 1                tau1_artery
# 2                tau1_artery
# 3                tau1_artery
# 4                tau1_artery
# 5                tau1_artery
# ..                       ...
# 539  ratio_AV_medianDiameter
# 540  ratio_AV_medianDiameter
# 541  ratio_AV_medianDiameter
# 542  ratio_AV_medianDiameter
# 543  ratio_AV_medianDiameter
#
# [447 rows x 5 columns]

# %% [markdown]
# ### - Rename diseases and delete non relevants
# #### In the GWAS catalog sometimes the names are pretty long, after a first inspection, go back here and rename them

# %%
df_gene_disease_filtered['disease']= df_gene_disease_filtered['MAPPED_TRAIT']

## 'age at diagnosis, type 1 diabeter mellitus' -> 'type 1 diabeter mellitus'
df_gene_disease_filtered['disease']=df_gene_disease_filtered['disease'].replace("age at diagnosis, type 1 diabetes mellitus","type 1 diabeter mellitus")
df_gene_disease_filtered['disease']=df_gene_disease_filtered['disease'].replace("autoimmune thyroid disease, obsolete_common variable immunodeficiency, type 1 diabetes mellitus, ankylosing spondylitis, psoriasis, celiac disease, ulcerative colitis, Crohn's disease, autoimmune disease, juvenile idiopathic arthritis, systemic lupus erythematosus","type 1 diabeter mellitus")
df_gene_disease_filtered['disease']=df_gene_disease_filtered['disease'].replace("HDL cholesterol change measurement, response to fenofibrate","HDL cholesterol change measurement")
df_gene_disease_filtered['disease']=df_gene_disease_filtered['disease'].replace("HDL cholesterol change measurement, response to simvastatin, response to fenofibrate","HDL cholesterol change measurement")
df_gene_disease_filtered['disease']=df_gene_disease_filtered['disease'].replace("refractive error, age at onset, Myopia","Myopia")
df_gene_disease_filtered['disease']=df_gene_disease_filtered['disease'].replace("cutaneous melanoma, hair color","hair color")
df_gene_disease_filtered['disease']=df_gene_disease_filtered['disease'].replace("systolic blood pressure, alcohol drinking","systolic blood pressure")
df_gene_disease_filtered['disease']=df_gene_disease_filtered['disease'].replace("diastolic blood pressure, alcohol drinking","diastolic blood pressure")

## 'autoimmune thyroid disease, obsolete_common variable immunodeficiency, type 1 diabetes mellitus, ankylosing spondylitis, psoriasis, celiac disease, ulcerative colitis, Crohn's disease, autoimmune disease, juvenile idiopathic arthritis, systemic lupus erythematosus' -> 'type 1 diabeter mellitus'
#### DROP NON RELEVANT DISEASES:
drop_disease_list = ["response to darapladib, Diarrhea", "vitamin B12 measurement",
                    'heart rate response to exercise']

for i_disease in drop_disease_list:
    df_gene_disease_filtered.drop(df_gene_disease_filtered.loc[df_gene_disease_filtered['disease']==i_disease].index, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /SSD/home/sofia/.local/lib/python3.6/site-packages/pandas/core/frame.py:3994: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ### - Drop duplicated columns

# %%
df_gene_disease_filtered.drop(columns=['Unnamed: 0', 'MAPPED_TRAIT'], inplace=True)
print(len(df_gene_disease_filtered))
df_gene_disease_filtered.drop_duplicates(subset=None, keep='first', inplace=True)
print(len(df_gene_disease_filtered))
# Out:
# 427
# 132
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### SHOW RESULTS:

# %% [markdown]
# ### A) Show results TEXT:

# %%
# Relevant columns df_gene_disease_filtered['gene', 'Trait', 'disease']
diseases_list = df_gene_disease_filtered['disease'].to_list()

mylist = list(dict.fromkeys(diseases_list))
print(mylist)
# Out:
# ['Ischemic stroke', 'Ischemic stroke, venous thromboembolism, stroke, Abnormal thrombosis, deep vein thrombosis, pulmonary embolism', 'HDL cholesterol change measurement', 'Myopia', 'heart rate', 'type 1 diabetes mellitus', 'type 2 diabetes mellitus', 'diastolic blood pressure', 'myocardial infarction', 'stroke', 'coronary artery disease', 'cataract', 'systolic blood pressure', 'arterial stiffness measurement', 'type 1 diabeter mellitus', 'venous thromboembolism', 'resting heart rate', 'type 2 diabetes mellitus, coronary artery disease', 'eye color', 'pathological myopia', 'hair color', 'cardioembolic stroke', 'skin pigmentation', 'large artery stroke', 'body mass index, coronary artery disease']

# %%
df_new=pd.DataFrame([])
for i in range(len(mylist)):
    print(mylist[i])
    df_aux = df_gene_disease_filtered[df_gene_disease_filtered['disease']== mylist[i]]
    print(df_aux)
    print('\n')
# Out:
# Ischemic stroke
#       gene                                INITIAL SAMPLE SIZE        Trait  \
# 1    LRCH1  34,217 European ancestry cases, 406,111 Europe...  tau1_artery
# 65   LRCH1  34,217 European ancestry cases, 406,111 Europe...  ratio_AV_DF
# 97   PDE3A  34,217 European ancestry cases, 406,111 Europe...      D_A_std
# 129  SH2B3  34,217 European ancestry cases, 406,111 Europe...      D_V_std
# 257   ILF3  34,217 European ancestry cases, 406,111 Europe...     ratio_VD
# 385  SH2B3  34,217 European ancestry cases, 406,111 Europe...      eq_CRVE
#
#              disease
# 1    Ischemic stroke
# 65   Ischemic stroke
# 97   Ischemic stroke
# 129  Ischemic stroke
# 257  Ischemic stroke
# 385  Ischemic stroke
#
#
# Ischemic stroke, venous thromboembolism, stroke, Abnormal thrombosis, deep vein thrombosis, pulmonary embolism
#     gene                                INITIAL SAMPLE SIZE        Trait  \
# 3  PROCR  6,135 European ancestry cases, 252,827 Europea...  tau1_artery
#
#                                              disease
# 3  Ischemic stroke, venous thromboembolism, strok...
#
#
# HDL cholesterol change measurement
#        gene                                INITIAL SAMPLE SIZE        Trait  \
# 4    TGFBR3  781 European ancestry individuals, 138 African...  tau1_artery
# 132  SGK223                1,594 European ancestry individuals      D_V_std
# 388  SGK223                1,594 European ancestry individuals      eq_CRVE
#
#                                 disease
# 4    HDL cholesterol change measurement
# 132  HDL cholesterol change measurement
# 388  HDL cholesterol change measurement
#
#
# Myopia
#          gene                                INITIAL SAMPLE SIZE  \
# 5       PDE3A  145,366 European ancestry individuals, 2,610 E...
# 37   C17orf47  145,366 European ancestry individuals, 2,610 E...
# 69      PDE3A  145,366 European ancestry individuals, 2,610 E...
# 101     PDE3A  145,366 European ancestry individuals, 2,610 E...
# 133      FLT1  145,366 European ancestry individuals, 2,610 E...
# 165   GATAD2A  145,366 European ancestry individuals, 2,610 E...
# 197   GATAD2A  145,366 European ancestry individuals, 2,610 E...
# 229   GATAD2A  145,366 European ancestry individuals, 2,610 E...
# 389      FLT1  145,366 European ancestry individuals, 2,610 E...
#
#               Trait disease
# 5       tau1_artery  Myopia
# 37        tau1_vein  Myopia
# 69      ratio_AV_DF  Myopia
# 101         D_A_std  Myopia
# 133         D_V_std  Myopia
# 165    bifurcations  Myopia
# 197  VD_orig_artery  Myopia
# 229    VD_orig_vein  Myopia
# 389         eq_CRVE  Myopia
#
#
# heart rate
#       gene                                INITIAL SAMPLE SIZE        Trait  \
# 10   ACTN4  85,787 European ancestry individuals, 6,568 In...  tau1_artery
# 42   ACTN4  85,787 European ancestry individuals, 6,568 In...    tau1_vein
# 74    CD34  85,787 European ancestry individuals, 6,568 In...  ratio_AV_DF
# 138  ACTN4  85,787 European ancestry individuals, 6,568 In...      D_V_std
# 394  ACTN4  85,787 European ancestry individuals, 6,568 In...      eq_CRVE
#
#         disease
# 10   heart rate
# 42   heart rate
# 74   heart rate
# 138  heart rate
# 394  heart rate
#
#
# type 1 diabetes mellitus
#      gene                                INITIAL SAMPLE SIZE        Trait  \
# 11  FARP2  20,065 European ancestry cases, 33,065 Europea...  tau1_artery
#
#                      disease
# 11  type 1 diabetes mellitus
#
#
# type 2 diabetes mellitus
#        gene                                INITIAL SAMPLE SIZE  \
# 13     GIPR  12,171 European ancestry cases, 56,862 Europea...
# 77    ZZEF1  up to 48,286 European ancestry cases, up to 25...
# 141   KIF11  2,277 African American cases, 3,098 East Asian...
# 173  TM6SF2  up to 48,286 European ancestry cases, up to 25...
# 205  TM6SF2  up to 48,286 European ancestry cases, up to 25...
# 237  TM6SF2  up to 48,286 European ancestry cases, up to 25...
# 269   PINX1  61,714 European ancestry cases, 1,178 Pakistan...
#
#               Trait                   disease
# 13      tau1_artery  type 2 diabetes mellitus
# 77      ratio_AV_DF  type 2 diabetes mellitus
# 141         D_V_std  type 2 diabetes mellitus
# 173    bifurcations  type 2 diabetes mellitus
# 205  VD_orig_artery  type 2 diabetes mellitus
# 237    VD_orig_vein  type 2 diabetes mellitus
# 269        ratio_VD  type 2 diabetes mellitus
#
#
# diastolic blood pressure
#         gene                                INITIAL SAMPLE SIZE  \
# 15    SYNPO2              757,601 European ancestry individuals
# 47   TMEM107              757,601 European ancestry individuals
# 79    ZNF423              757,601 European ancestry individuals
# 111    PDE3A        up to 201,529 European ancestry individuals
# 143    SH2B3               69,395 European ancestry individuals
# 207    PLCB1              140,886 European ancestry individuals
# 239    PLCB1              140,886 European ancestry individuals
# 271    PINX1  63,607 European ancestry drinkers, 10,193 Afri...
# 335    PPM1A              757,601 European ancestry individuals
# 399    SH2B3               69,395 European ancestry individuals
# 431    MECOM               69,395 European ancestry individuals
# 463      ADO  up to 165,276 European ancestry individuals, u...
#
#                      Trait                   disease
# 15             tau1_artery  diastolic blood pressure
# 47               tau1_vein  diastolic blood pressure
# 79             ratio_AV_DF  diastolic blood pressure
# 111                D_A_std  diastolic blood pressure
# 143                D_V_std  diastolic blood pressure
# 207         VD_orig_artery  diastolic blood pressure
# 239           VD_orig_vein  diastolic blood pressure
# 271               ratio_VD  diastolic blood pressure
# 335         mean_angle_tva  diastolic blood pressure
# 399                eq_CRVE  diastolic blood pressure
# 431        ratio_CRAE_CRVE  diastolic blood pressure
# 463  medianDiameter_artery  diastolic blood pressure
#
#
# myocardial infarction
#         gene                                INITIAL SAMPLE SIZE  \
# 18     WDR12  2,967 European ancestry cases, 3,075 European ...
# 50   PLEKHG1  14,825 European ancestry cases, 44,000 Europea...
# 82      SMG6  27,509 European ancestry cases, 130 African Am...
# 114     SMG6  27,509 European ancestry cases, 130 African Am...
# 146    BCAS3  27,509 European ancestry cases, 130 African Am...
# 178    ABHD2  14,825 European ancestry cases, 44,000 Europea...
# 210   RSPH6A  14,825 European ancestry cases, 44,000 Europea...
# 242    ABHD2  14,825 European ancestry cases, 44,000 Europea...
# 274  CYP17A1  14,825 European ancestry cases, 44,000 Europea...
# 306   CXCL12  2,967 European ancestry cases, 3,075 European ...
# 370    LAMB2  14,825 European ancestry cases, 44,000 Europea...
# 402    SH2B3  27,509 European ancestry cases, 130 African Am...
#
#               Trait                disease
# 18      tau1_artery  myocardial infarction
# 50        tau1_vein  myocardial infarction
# 82      ratio_AV_DF  myocardial infarction
# 114         D_A_std  myocardial infarction
# 146         D_V_std  myocardial infarction
# 178    bifurcations  myocardial infarction
# 210  VD_orig_artery  myocardial infarction
# 242    VD_orig_vein  myocardial infarction
# 274        ratio_VD  myocardial infarction
# 306  mean_angle_taa  myocardial infarction
# 370         eq_CRAE  myocardial infarction
# 402         eq_CRVE  myocardial infarction
#
#
# stroke
#       gene                                INITIAL SAMPLE SIZE        Trait  \
# 23   LRCH1  40,585 European ancestry cases, 406,111 Europe...  tau1_artery
# 55   RNF43  40,585 European ancestry cases, 406,111 Europe...    tau1_vein
# 87   LRCH1  40,585 European ancestry cases, 406,111 Europe...  ratio_AV_DF
# 119  FOXF2  40,585 European ancestry cases, 406,111 Europe...      D_A_std
# 151  SH2B3  40,585 European ancestry cases, 406,111 Europe...      D_V_std
# 407  SH2B3  40,585 European ancestry cases, 406,111 Europe...      eq_CRVE
#
#     disease
# 23   stroke
# 55   stroke
# 87   stroke
# 119  stroke
# 151  stroke
# 407  stroke
#
#
# coronary artery disease
#         gene                                INITIAL SAMPLE SIZE  \
# 26     WDR12  22,233 European ancestry cases, 64,762 Europea...
# 58      RHOA  18,467 European and unknown ancestry cases, 45...
# 90      SMG6  42,096 European ancestry cases, 361 African Am...
# 122     SMG6  42,096 European ancestry cases, 361 African Am...
# 154    SH2B3  22,233 European ancestry cases, 64,762 Europea...
# 314   CXCL12  22,233 European ancestry cases, 64,762 Europea...
# 378     RHOA  18,467 European and unknown ancestry cases, 45...
# 410    SH2B3  22,233 European ancestry cases, 64,762 Europea...
# 442  C6orf48  25,892 Japanese ancestry cases, 95,342 Europea...
#
#                Trait                  disease
# 26       tau1_artery  coronary artery disease
# 58         tau1_vein  coronary artery disease
# 90       ratio_AV_DF  coronary artery disease
# 122          D_A_std  coronary artery disease
# 154          D_V_std  coronary artery disease
# 314   mean_angle_taa  coronary artery disease
# 378          eq_CRAE  coronary artery disease
# 410          eq_CRVE  coronary artery disease
# 442  ratio_CRAE_CRVE  coronary artery disease
#
#
# cataract
#        gene                                INITIAL SAMPLE SIZE  \
# 29    DIRC3  28,092 non-Hispanic White ancestry cases, 50,4...
# 125  NPLOC4  28,092 non-Hispanic White ancestry cases, 50,4...
# 157  NPLOC4  28,092 non-Hispanic White ancestry cases, 50,4...
# 189    OCA2  28,092 non-Hispanic White ancestry cases, 50,4...
# 253    OCA2  28,092 non-Hispanic White ancestry cases, 50,4...
# 413  NPLOC4  28,092 non-Hispanic White ancestry cases, 50,4...
# 509    OCA2  28,092 non-Hispanic White ancestry cases, 50,4...
#
#                    Trait   disease
# 29           tau1_artery  cataract
# 125              D_A_std  cataract
# 157              D_V_std  cataract
# 189         bifurcations  cataract
# 253         VD_orig_vein  cataract
# 413              eq_CRVE  cataract
# 509  medianDiameter_vein  cataract
#
#
# systolic blood pressure
#         gene                                INITIAL SAMPLE SIZE  \
# 31   FAM129B              757,601 European ancestry individuals
# 63     ARIH2              757,601 European ancestry individuals
# 95     LRCH1              757,601 European ancestry individuals
# 127    PDE3A        up to 201,529 European ancestry individuals
# 159    BCAS3              757,601 European ancestry individuals
# 191   CTNNB1              757,601 European ancestry individuals
# 223   CTNNB1              757,601 European ancestry individuals
# 255   CTNNB1              757,601 European ancestry individuals
# 287    AS3MT  63,608 European ancestry drinkers, 10,193 Afri...
# 383    ARIH2              757,601 European ancestry individuals
# 415     MSRA              757,601 European ancestry individuals
# 447    MECOM               69,395 European ancestry individuals
# 479      ADO  up to 165,276 European ancestry individuals, u...
#
#                      Trait                  disease
# 31             tau1_artery  systolic blood pressure
# 63               tau1_vein  systolic blood pressure
# 95             ratio_AV_DF  systolic blood pressure
# 127                D_A_std  systolic blood pressure
# 159                D_V_std  systolic blood pressure
# 191           bifurcations  systolic blood pressure
# 223         VD_orig_artery  systolic blood pressure
# 255           VD_orig_vein  systolic blood pressure
# 287               ratio_VD  systolic blood pressure
# 383                eq_CRAE  systolic blood pressure
# 415                eq_CRVE  systolic blood pressure
# 447        ratio_CRAE_CRVE  systolic blood pressure
# 479  medianDiameter_artery  systolic blood pressure
#
#
# arterial stiffness measurement
#        gene                    INITIAL SAMPLE SIZE           Trait  \
# 32    TEX41  127,121 European ancestry individuals       tau1_vein
# 192  RSPH6A  127,121 European ancestry individuals  VD_orig_artery
#
#                             disease
# 32   arterial stiffness measurement
# 192  arterial stiffness measurement
#
#
# type 1 diabeter mellitus
#       gene                                INITIAL SAMPLE SIZE  \
# 43    DAG1  97 European ancestry thyroiditis cases, 107 Eu...
# 139   FUT2  97 European ancestry thyroiditis cases, 107 Eu...
# 171    EYS               12,539 European ancestry individuals
# 235    EYS               12,539 European ancestry individuals
# 267   FUT2  97 European ancestry thyroiditis cases, 107 Eu...
# 299  LPHN2  97 European ancestry thyroiditis cases, 107 Eu...
# 395   FUT2  97 European ancestry thyroiditis cases, 107 Eu...
# 427   FUT2  97 European ancestry thyroiditis cases, 107 Eu...
# 523   FUT2  97 European ancestry thyroiditis cases, 107 Eu...
#
#                        Trait                   disease
# 43                 tau1_vein  type 1 diabeter mellitus
# 139                  D_V_std  type 1 diabeter mellitus
# 171             bifurcations  type 1 diabeter mellitus
# 235             VD_orig_vein  type 1 diabeter mellitus
# 267                 ratio_VD  type 1 diabeter mellitus
# 299           mean_angle_taa  type 1 diabeter mellitus
# 395                  eq_CRVE  type 1 diabeter mellitus
# 427          ratio_CRAE_CRVE  type 1 diabeter mellitus
# 523  ratio_AV_medianDiameter  type 1 diabeter mellitus
#
#
# venous thromboembolism
#      gene                                INITIAL SAMPLE SIZE        Trait  \
# 72   SMG6  29,435 European ancestry cases, 799 African Am...  ratio_AV_DF
# 104  SMG6  29,435 European ancestry cases, 799 African Am...      D_A_std
#
#                     disease
# 72   venous thromboembolism
# 104  venous thromboembolism
#
#
# resting heart rate
#       gene                                INITIAL SAMPLE SIZE           Trait  \
# 106  PDE3A  127,919 European ancestry individuals, 2,478 A...         D_A_std
# 330  TANC1  127,919 European ancestry individuals, 2,478 A...  mean_angle_tva
#
#                 disease
# 106  resting heart rate
# 330  resting heart rate
#
#
# type 2 diabetes mellitus, coronary artery disease
#       gene                                INITIAL SAMPLE SIZE    Trait  \
# 109  PDE3A  56,285 European ancestry coronary heart diseas...  D_A_std
#
#                                                disease
# 109  type 2 diabetes mellitus, coronary artery disease
#
#
# eye color
#       gene                                INITIAL SAMPLE SIZE  \
# 134  HERC2  925 Erasmus Rucphen individuals, 481 European ...
# 166  HERC2  925 Erasmus Rucphen individuals, 481 European ...
# 198  HERC2  925 Erasmus Rucphen individuals, 481 European ...
# 230  HERC2  925 Erasmus Rucphen individuals, 481 European ...
# 454  HERC2  925 Erasmus Rucphen individuals, 481 European ...
# 486  HERC2  925 Erasmus Rucphen individuals, 481 European ...
#
#                      Trait    disease
# 134                D_V_std  eye color
# 166           bifurcations  eye color
# 198         VD_orig_artery  eye color
# 230           VD_orig_vein  eye color
# 454  medianDiameter_artery  eye color
# 486    medianDiameter_vein  eye color
#
#
# pathological myopia
#       gene                                INITIAL SAMPLE SIZE    Trait  \
# 144  GATA4  187 European ancestry cases, 1064 European anc...  D_V_std
# 400  GATA4  187 European ancestry cases, 1064 European anc...  eq_CRVE
#
#                  disease
# 144  pathological myopia
# 400  pathological myopia
#
#
# hair color
#       gene                                INITIAL SAMPLE SIZE  \
# 145  HERC2  36,760 European ancestry cutaneous melanoma ca...
# 177  HERC2  36,760 European ancestry cutaneous melanoma ca...
# 209  HERC2  36,760 European ancestry cutaneous melanoma ca...
# 241  HERC2  36,760 European ancestry cutaneous melanoma ca...
# 465  HERC2  36,760 European ancestry cutaneous melanoma ca...
# 497  HERC2  36,760 European ancestry cutaneous melanoma ca...
#
#                      Trait     disease
# 145                D_V_std  hair color
# 177           bifurcations  hair color
# 209         VD_orig_artery  hair color
# 241           VD_orig_vein  hair color
# 465  medianDiameter_artery  hair color
# 497    medianDiameter_vein  hair color
#
#
# cardioembolic stroke
#     gene                                INITIAL SAMPLE SIZE    Trait  \
# 147  HK1  7,193 European ancestry cases, 406,111 Europea...  D_V_std
#
#                   disease
# 147  cardioembolic stroke
#
#
# skin pigmentation
#       gene                  INITIAL SAMPLE SIZE                  Trait  \
# 153  HERC2  9,316 European ancestry individuals                D_V_std
# 185  HERC2  9,316 European ancestry individuals           bifurcations
# 217  HERC2  9,316 European ancestry individuals         VD_orig_artery
# 249  HERC2  9,316 European ancestry individuals           VD_orig_vein
# 473  HERC2  9,316 European ancestry individuals  medianDiameter_artery
# 505  HERC2  9,316 European ancestry individuals    medianDiameter_vein
#
#                disease
# 153  skin pigmentation
# 185  skin pigmentation
# 217  skin pigmentation
# 249  skin pigmentation
# 473  skin pigmentation
# 505  skin pigmentation
#
#
# large artery stroke
#        gene                                INITIAL SAMPLE SIZE  \
# 183  SH3YL1  up to 2,286 European ancestry cases, up to 376...
# 215  SH3YL1  up to 2,286 European ancestry cases, up to 376...
#
#               Trait              disease
# 183    bifurcations  large artery stroke
# 215  VD_orig_artery  large artery stroke
#
#
# body mass index, coronary artery disease
#       gene                                INITIAL SAMPLE SIZE  \
# 282  NT5C2  464,176 European ancestry individuals, 59,353 ...
# 474  NT5C2  464,176 European ancestry individuals, 59,353 ...
#
#                      Trait                                   disease
# 282               ratio_VD  body mass index, coronary artery disease
# 474  medianDiameter_artery  body mass index, coronary artery disease

# %% [markdown]
# ### B) Plots

# %% [markdown]
# #### B1)  STEM PLOT VASCULAR GENES (PASCAL)

# %%
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 14
plt.figure(figsize=(15, 5))
plt.xlabel('Genes')
plt.ylabel('Phenotypes')

plt.scatter(df_gene_disease_filtered['gene'], df_gene_disease_filtered['Trait'])
plt.grid()
plt.stem(df_gene_disease_filtered['gene'], df_gene_disease_filtered['Trait'], markerfmt='.', basefmt = " ")
plt.xticks(df_gene_disease_filtered['gene'], rotation=90)
#plt.savefig('/Users/sortinve/Desktop/General_PhD/Presentaciones_PhD/Poster_eccb2022/genes_phenos.png',  transparent=True, bbox_inches='tight', pad_inches=0.1, dpi=150)
# Out:
# ([<matplotlib.axis.XTick at 0x7f05a1c7d160>,
#   <matplotlib.axis.XTick at 0x7f05a1c6fcf8>,
#   <matplotlib.axis.XTick at 0x7f05a1d04c50>,
#   <matplotlib.axis.XTick at 0x7f0599c602b0>,
#   <matplotlib.axis.XTick at 0x7f0599c60748>,
#   <matplotlib.axis.XTick at 0x7f0599c60be0>,
#   <matplotlib.axis.XTick at 0x7f0599c6a0b8>,
#   <matplotlib.axis.XTick at 0x7f0599c6a550>,
#   <matplotlib.axis.XTick at 0x7f0599c60048>,
#   <matplotlib.axis.XTick at 0x7f0599c6a748>,
#   <matplotlib.axis.XTick at 0x7f0599c6abe0>,
#   <matplotlib.axis.XTick at 0x7f0599bf10b8>,
#   <matplotlib.axis.XTick at 0x7f0599bf1550>,
#   <matplotlib.axis.XTick at 0x7f0599bf19e8>,
#   <matplotlib.axis.XTick at 0x7f0599bf1e80>,
#   <matplotlib.axis.XTick at 0x7f0599bf9358>,
#   <matplotlib.axis.XTick at 0x7f0599bf97f0>,
#   <matplotlib.axis.XTick at 0x7f0599bf1160>,
#   <matplotlib.axis.XTick at 0x7f0599c60cf8>,
#   <matplotlib.axis.XTick at 0x7f0599bf9a58>,
#   <matplotlib.axis.XTick at 0x7f0599bf9ef0>,
#   <matplotlib.axis.XTick at 0x7f0599c023c8>,
#   <matplotlib.axis.XTick at 0x7f0599c02860>,
#   <matplotlib.axis.XTick at 0x7f0599c02cf8>,
#   <matplotlib.axis.XTick at 0x7f0599c0a1d0>,
#   <matplotlib.axis.XTick at 0x7f0599c0a668>,
#   <matplotlib.axis.XTick at 0x7f0599c025f8>,
#   <matplotlib.axis.XTick at 0x7f0599bf9588>,
#   <matplotlib.axis.XTick at 0x7f0599c0a438>,
#   <matplotlib.axis.XTick at 0x7f0599c0ad68>,
#   <matplotlib.axis.XTick at 0x7f0599c13240>,
#   <matplotlib.axis.XTick at 0x7f0599c136d8>,
#   <matplotlib.axis.XTick at 0x7f0599c13b70>,
#   <matplotlib.axis.XTick at 0x7f0599c1b048>,
#   <matplotlib.axis.XTick at 0x7f0599c1b4e0>,
#   <matplotlib.axis.XTick at 0x7f0599c1b978>,
#   <matplotlib.axis.XTick at 0x7f0599c0af98>,
#   <matplotlib.axis.XTick at 0x7f0599c02198>,
#   <matplotlib.axis.XTick at 0x7f0599c1bb70>,
#   <matplotlib.axis.XTick at 0x7f0599c26080>,
#   <matplotlib.axis.XTick at 0x7f0599c264e0>,
#   <matplotlib.axis.XTick at 0x7f0599c26978>,
#   <matplotlib.axis.XTick at 0x7f0599c26e10>,
#   <matplotlib.axis.XTick at 0x7f0599c2d2e8>,
#   <matplotlib.axis.XTick at 0x7f0599c2d780>,
#   <matplotlib.axis.XTick at 0x7f0599c26668>,
#   <matplotlib.axis.XTick at 0x7f0599c1b9b0>,
#   <matplotlib.axis.XTick at 0x7f0599c2d4a8>,
#   <matplotlib.axis.XTick at 0x7f0599c2de80>,
#   <matplotlib.axis.XTick at 0x7f0599bb6358>,
#   <matplotlib.axis.XTick at 0x7f0599bb67f0>,
#   <matplotlib.axis.XTick at 0x7f0599bb6c88>,
#   <matplotlib.axis.XTick at 0x7f0599bbf160>,
#   <matplotlib.axis.XTick at 0x7f0599bbf5f8>,
#   <matplotlib.axis.XTick at 0x7f0599bbfa90>,
#   <matplotlib.axis.XTick at 0x7f0599bb60f0>,
#   <matplotlib.axis.XTick at 0x7f0599c26208>,
#   <matplotlib.axis.XTick at 0x7f0599bbfc88>,
#   <matplotlib.axis.XTick at 0x7f0599bc7160>,
#   <matplotlib.axis.XTick at 0x7f0599bc75f8>,
#   <matplotlib.axis.XTick at 0x7f0599bc7a90>,
#   <matplotlib.axis.XTick at 0x7f0599bc7f28>,
#   <matplotlib.axis.XTick at 0x7f0599bd0400>,
#   <matplotlib.axis.XTick at 0x7f0599bd0898>,
#   <matplotlib.axis.XTick at 0x7f0599bc7390>,
#   <matplotlib.axis.XTick at 0x7f0599c2dc50>,
#   <matplotlib.axis.XTick at 0x7f0599bd01d0>,
#   <matplotlib.axis.XTick at 0x7f0599bd0f98>,
#   <matplotlib.axis.XTick at 0x7f0599bda470>,
#   <matplotlib.axis.XTick at 0x7f0599bda908>,
#   <matplotlib.axis.XTick at 0x7f0599bdada0>,
#   <matplotlib.axis.XTick at 0x7f0599be2278>,
#   <matplotlib.axis.XTick at 0x7f0599be2710>,
#   <matplotlib.axis.XTick at 0x7f0599be2ba8>,
#   <matplotlib.axis.XTick at 0x7f0599bda240>,
#   <matplotlib.axis.XTick at 0x7f0599bc72e8>,
#   <matplotlib.axis.XTick at 0x7f0599be2da0>,
#   <matplotlib.axis.XTick at 0x7f0599bed278>,
#   <matplotlib.axis.XTick at 0x7f0599bed710>,
#   <matplotlib.axis.XTick at 0x7f0599bedba8>,
#   <matplotlib.axis.XTick at 0x7f0599b74080>,
#   <matplotlib.axis.XTick at 0x7f0599b74518>,
#   <matplotlib.axis.XTick at 0x7f0599b749b0>,
#   <matplotlib.axis.XTick at 0x7f0599bed4a8>,
#   <matplotlib.axis.XTick at 0x7f0599bd0c88>,
#   <matplotlib.axis.XTick at 0x7f0599b742e8>,
#   <matplotlib.axis.XTick at 0x7f0599b7e0f0>,
#   <matplotlib.axis.XTick at 0x7f0599b7e588>,
#   <matplotlib.axis.XTick at 0x7f0599b7ea20>,
#   <matplotlib.axis.XTick at 0x7f0599b7eeb8>,
#   <matplotlib.axis.XTick at 0x7f0599b84390>,
#   <matplotlib.axis.XTick at 0x7f0599b84828>,
#   <matplotlib.axis.XTick at 0x7f0599b84cc0>,
#   <matplotlib.axis.XTick at 0x7f0599b7e198>,
#   <matplotlib.axis.XTick at 0x7f0599b84dd8>,
#   <matplotlib.axis.XTick at 0x7f0599b84eb8>,
#   <matplotlib.axis.XTick at 0x7f0599b8d390>,
#   <matplotlib.axis.XTick at 0x7f0599b8d828>,
#   <matplotlib.axis.XTick at 0x7f0599b8dcc0>,
#   <matplotlib.axis.XTick at 0x7f0599b97198>,
#   <matplotlib.axis.XTick at 0x7f0599b97630>,
#   <matplotlib.axis.XTick at 0x7f0599b97ac8>,
#   <matplotlib.axis.XTick at 0x7f0599b8d5c0>,
#   <matplotlib.axis.XTick at 0x7f0599b74d30>,
#   <matplotlib.axis.XTick at 0x7f0599b97400>,
#   <matplotlib.axis.XTick at 0x7f0599b9f208>,
#   <matplotlib.axis.XTick at 0x7f0599b9f6a0>,
#   <matplotlib.axis.XTick at 0x7f0599b9fb38>,
#   <matplotlib.axis.XTick at 0x7f0599ba8048>,
#   <matplotlib.axis.XTick at 0x7f0599ba84a8>,
#   <matplotlib.axis.XTick at 0x7f0599ba8940>,
#   <matplotlib.axis.XTick at 0x7f0599ba8dd8>,
#   <matplotlib.axis.XTick at 0x7f0599b97f60>,
#   <matplotlib.axis.XTick at 0x7f0599ba8b70>,
#   <matplotlib.axis.XTick at 0x7f0599b31048>,
#   <matplotlib.axis.XTick at 0x7f0599b314a8>,
#   <matplotlib.axis.XTick at 0x7f0599b31940>,
#   <matplotlib.axis.XTick at 0x7f0599b31dd8>,
#   <matplotlib.axis.XTick at 0x7f0599b3a2b0>,
#   <matplotlib.axis.XTick at 0x7f0599b3a748>,
#   <matplotlib.axis.XTick at 0x7f0599b3abe0>,
#   <matplotlib.axis.XTick at 0x7f0599b31630>,
#   <matplotlib.axis.XTick at 0x7f0599b9fcc0>,
#   <matplotlib.axis.XTick at 0x7f0599bedd68>,
#   <matplotlib.axis.XTick at 0x7f0599c0a7f0>,
#   <matplotlib.axis.XTick at 0x7f0599b3a470>,
#   <matplotlib.axis.XTick at 0x7f0599b43320>,
#   <matplotlib.axis.XTick at 0x7f0599b437b8>,
#   <matplotlib.axis.XTick at 0x7f0599b43c50>,
#   <matplotlib.axis.XTick at 0x7f0599b4a128>,
#   <matplotlib.axis.XTick at 0x7f0599b4a5c0>,
#   <matplotlib.axis.XTick at 0x7f05a1d04e10>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# #### B2)  STEM PLOT DISEASES GENES (GWAS CATALOG)

# %%
plt.figure(figsize=(15, 6))
plt.xlabel('Genes')
plt.ylabel('Diseases')

plt.scatter(df_gene_disease_filtered['gene'], df_gene_disease_filtered['disease'])
plt.grid()
plt.gca().invert_yaxis()
plt.xticks(df_gene_disease_filtered['gene'], rotation=90)
#plt.savefig('/Users/sortinve/Desktop/General_PhD/Presentaciones_PhD/Poster_eccb2022/genes_diseases.png',  transparent=True, bbox_inches='tight', pad_inches=0.1, dpi=150)
# Out:
# ([<matplotlib.axis.XTick at 0x7f05999dfa90>,
#   <matplotlib.axis.XTick at 0x7f05999df710>,
#   <matplotlib.axis.XTick at 0x7f05999d9080>,
#   <matplotlib.axis.XTick at 0x7f0598177630>,
#   <matplotlib.axis.XTick at 0x7f0598177ac8>,
#   <matplotlib.axis.XTick at 0x7f0598177f60>,
#   <matplotlib.axis.XTick at 0x7f0598177898>,
#   <matplotlib.axis.XTick at 0x7f0598182470>,
#   <matplotlib.axis.XTick at 0x7f0598182908>,
#   <matplotlib.axis.XTick at 0x7f0598182da0>,
#   <matplotlib.axis.XTick at 0x7f059818b278>,
#   <matplotlib.axis.XTick at 0x7f059818b710>,
#   <matplotlib.axis.XTick at 0x7f059818bba8>,
#   <matplotlib.axis.XTick at 0x7f05981930b8>,
#   <matplotlib.axis.XTick at 0x7f0598193518>,
#   <matplotlib.axis.XTick at 0x7f059818b4e0>,
#   <matplotlib.axis.XTick at 0x7f0598182518>,
#   <matplotlib.axis.XTick at 0x7f0598193860>,
#   <matplotlib.axis.XTick at 0x7f0598193cf8>,
#   <matplotlib.axis.XTick at 0x7f059819d1d0>,
#   <matplotlib.axis.XTick at 0x7f059819d668>,
#   <matplotlib.axis.XTick at 0x7f059819db00>,
#   <matplotlib.axis.XTick at 0x7f059819df98>,
#   <matplotlib.axis.XTick at 0x7f05981a7470>,
#   <matplotlib.axis.XTick at 0x7f059819d828>,
#   <matplotlib.axis.XTick at 0x7f0598193978>,
#   <matplotlib.axis.XTick at 0x7f05981a7240>,
#   <matplotlib.axis.XTick at 0x7f05981a7c50>,
#   <matplotlib.axis.XTick at 0x7f059812f128>,
#   <matplotlib.axis.XTick at 0x7f059812f5c0>,
#   <matplotlib.axis.XTick at 0x7f059812fa58>,
#   <matplotlib.axis.XTick at 0x7f059812fef0>,
#   <matplotlib.axis.XTick at 0x7f05981373c8>,
#   <matplotlib.axis.XTick at 0x7f0598137860>,
#   <matplotlib.axis.XTick at 0x7f05981a7e80>,
#   <matplotlib.axis.XTick at 0x7f059819d390>,
#   <matplotlib.axis.XTick at 0x7f0598137a58>,
#   <matplotlib.axis.XTick at 0x7f0598137ef0>,
#   <matplotlib.axis.XTick at 0x7f05981413c8>,
#   <matplotlib.axis.XTick at 0x7f0598141860>,
#   <matplotlib.axis.XTick at 0x7f0598141cf8>,
#   <matplotlib.axis.XTick at 0x7f05981481d0>,
#   <matplotlib.axis.XTick at 0x7f0598148668>,
#   <matplotlib.axis.XTick at 0x7f05981415f8>,
#   <matplotlib.axis.XTick at 0x7f05981379b0>,
#   <matplotlib.axis.XTick at 0x7f0598148438>,
#   <matplotlib.axis.XTick at 0x7f0598148d68>,
#   <matplotlib.axis.XTick at 0x7f0598152240>,
#   <matplotlib.axis.XTick at 0x7f05981526d8>,
#   <matplotlib.axis.XTick at 0x7f0598152b70>,
#   <matplotlib.axis.XTick at 0x7f059815c080>,
#   <matplotlib.axis.XTick at 0x7f059815c4e0>,
#   <matplotlib.axis.XTick at 0x7f059815c978>,
#   <matplotlib.axis.XTick at 0x7f0598148f98>,
#   <matplotlib.axis.XTick at 0x7f0598141198>,
#   <matplotlib.axis.XTick at 0x7f059815cb70>,
#   <matplotlib.axis.XTick at 0x7f0598165080>,
#   <matplotlib.axis.XTick at 0x7f05981654e0>,
#   <matplotlib.axis.XTick at 0x7f0598165978>,
#   <matplotlib.axis.XTick at 0x7f0598165e10>,
#   <matplotlib.axis.XTick at 0x7f05980ee2e8>,
#   <matplotlib.axis.XTick at 0x7f05980ee780>,
#   <matplotlib.axis.XTick at 0x7f0598165668>,
#   <matplotlib.axis.XTick at 0x7f059815c9b0>,
#   <matplotlib.axis.XTick at 0x7f05980ee4a8>,
#   <matplotlib.axis.XTick at 0x7f05980eee80>,
#   <matplotlib.axis.XTick at 0x7f05980f7358>,
#   <matplotlib.axis.XTick at 0x7f05980f77f0>,
#   <matplotlib.axis.XTick at 0x7f05980f7c88>,
#   <matplotlib.axis.XTick at 0x7f0598100160>,
#   <matplotlib.axis.XTick at 0x7f05981005f8>,
#   <matplotlib.axis.XTick at 0x7f0598100a90>,
#   <matplotlib.axis.XTick at 0x7f05980f70f0>,
#   <matplotlib.axis.XTick at 0x7f0598165208>,
#   <matplotlib.axis.XTick at 0x7f0598100c88>,
#   <matplotlib.axis.XTick at 0x7f0598108160>,
#   <matplotlib.axis.XTick at 0x7f05981085f8>,
#   <matplotlib.axis.XTick at 0x7f0598108a90>,
#   <matplotlib.axis.XTick at 0x7f0598108f28>,
#   <matplotlib.axis.XTick at 0x7f0598112400>,
#   <matplotlib.axis.XTick at 0x7f0598112898>,
#   <matplotlib.axis.XTick at 0x7f0598108390>,
#   <matplotlib.axis.XTick at 0x7f05980f7da0>,
#   <matplotlib.axis.XTick at 0x7f0598141da0>,
#   <matplotlib.axis.XTick at 0x7f0598182048>,
#   <matplotlib.axis.XTick at 0x7f0598112c50>,
#   <matplotlib.axis.XTick at 0x7f059811c128>,
#   <matplotlib.axis.XTick at 0x7f059811c5c0>,
#   <matplotlib.axis.XTick at 0x7f059811ca58>,
#   <matplotlib.axis.XTick at 0x7f059811cef0>,
#   <matplotlib.axis.XTick at 0x7f05981243c8>,
#   <matplotlib.axis.XTick at 0x7f059811c2e8>,
#   <matplotlib.axis.XTick at 0x7f05980ee9b0>,
#   <matplotlib.axis.XTick at 0x7f0598124048>,
#   <matplotlib.axis.XTick at 0x7f0598124a58>,
#   <matplotlib.axis.XTick at 0x7f0598124ef0>,
#   <matplotlib.axis.XTick at 0x7f05980ad3c8>,
#   <matplotlib.axis.XTick at 0x7f05980ad860>,
#   <matplotlib.axis.XTick at 0x7f05980adcf8>,
#   <matplotlib.axis.XTick at 0x7f05980b51d0>,
#   <matplotlib.axis.XTick at 0x7f05980ada20>,
#   <matplotlib.axis.XTick at 0x7f0598124b70>,
#   <matplotlib.axis.XTick at 0x7f05980b5588>,
#   <matplotlib.axis.XTick at 0x7f05980b5940>,
#   <matplotlib.axis.XTick at 0x7f05980b5dd8>,
#   <matplotlib.axis.XTick at 0x7f05980bf2b0>,
#   <matplotlib.axis.XTick at 0x7f05980bf748>,
#   <matplotlib.axis.XTick at 0x7f05980bfbe0>,
#   <matplotlib.axis.XTick at 0x7f05980c70b8>,
#   <matplotlib.axis.XTick at 0x7f05980bf908>,
#   <matplotlib.axis.XTick at 0x7f05980b5a58>,
#   <matplotlib.axis.XTick at 0x7f05980c7438>,
#   <matplotlib.axis.XTick at 0x7f05980c7898>,
#   <matplotlib.axis.XTick at 0x7f05980c7d30>,
#   <matplotlib.axis.XTick at 0x7f05980d2208>,
#   <matplotlib.axis.XTick at 0x7f05980d26a0>,
#   <matplotlib.axis.XTick at 0x7f05980d2b38>,
#   <matplotlib.axis.XTick at 0x7f05980da048>,
#   <matplotlib.axis.XTick at 0x7f05980d2828>,
#   <matplotlib.axis.XTick at 0x7f05980c7940>,
#   <matplotlib.axis.XTick at 0x7f05980da390>,
#   <matplotlib.axis.XTick at 0x7f05980da7f0>,
#   <matplotlib.axis.XTick at 0x7f05980dac88>,
#   <matplotlib.axis.XTick at 0x7f05980e4160>,
#   <matplotlib.axis.XTick at 0x7f05980e45f8>,
#   <matplotlib.axis.XTick at 0x7f05980e4a90>,
#   <matplotlib.axis.XTick at 0x7f05980e4f28>,
#   <matplotlib.axis.XTick at 0x7f05980e4860>,
#   <matplotlib.axis.XTick at 0x7f05980da9b0>,
#   <matplotlib.axis.XTick at 0x7f059806d320>,
#   <matplotlib.axis.XTick at 0x7f059806d748>,
#   <matplotlib.axis.XTick at 0x7f059806dbe0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# #### B3)  STEM PLOT TRYING TO COMBAIN THE VASCULAR GENES (PASCAL) AND THE DISEASES GENES (GWAS CATALOG)

# %%
fig, ax1 = plt.subplots(figsize=(20, 7))
plt.grid()
color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.scatter(df_gene_disease_filtered['gene'], df_gene_disease_filtered['Trait'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
plt.xticks(df_gene_disease_filtered['gene'], rotation=90)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.scatter(df_gene_disease_filtered['gene'], df_gene_disease_filtered['disease'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
#plt.hlines(y=df_gene_disease_filtered['Trait'], xmin=0, xmax=df_gene_disease_filtered['Trait'], color='skyblue')
ax2.stem(df_gene_disease_filtered['gene'], df_gene_disease_filtered['disease'], markerfmt='.', basefmt = " ")


plt.xticks(df_gene_disease_filtered['gene'], rotation=90)
plt.grid()
fig.tight_layout()  # otherwise the right y-label is slightly clipped

#plt.stem(df_gene_disease_filtered['gene'], df_gene_disease_filtered['Trait'], markerfmt='.', basefmt = " ")
plt.grid()
#plt.savefig('/Users/sortinve/Desktop/General_PhD/Presentaciones_PhD/Poster_eccb2022/genes_phenos.png',  transparent=True, bbox_inches='tight', pad_inches=0.1, dpi=150)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(20, 7))
plt.grid()
color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.scatter(df_gene_disease_filtered['gene'], df_gene_disease_filtered['Trait'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
plt.xticks(df_gene_disease_filtered['gene'], rotation=90)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.scatter(df_gene_disease_filtered['gene'], df_gene_disease_filtered['disease'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
#plt.hlines(y=df_gene_disease_filtered['Trait'], xmin=0, xmax=df_gene_disease_filtered['Trait'], color='skyblue')
#ax2.stem(df_gene_disease_filtered['gene'], df_gene_disease_filtered['disease'], markerfmt='.', basefmt = " ")


plt.xticks(df_gene_disease_filtered['gene'], rotation=90)
plt.grid()
fig.tight_layout()  # otherwise the right y-label is slightly clipped

#plt.stem(df_gene_disease_filtered['gene'], df_gene_disease_filtered['Trait'], markerfmt='.', basefmt = " ")
plt.grid()
#plt.savefig('/Users/sortinve/Desktop/General_PhD/Presentaciones_PhD/Poster_eccb2022/genes_phenos.png',  transparent=True, bbox_inches='tight', pad_inches=0.1, dpi=150)
plt.show()

# %% [markdown]
# #### B4)  SANKEY PLOT VASCULAR GENES

# %%
sankey(df_gene_disease_filtered['gene'], df_gene_disease_filtered['Trait'],  aspect=10, fontsize=7)
# Get current figure
#plt.gca().invert_yaxis()
fig = plt.gcf()
# Set size in inches
fig.set_size_inches(6, 12)
# Set the color of the background to white
fig.set_facecolor("w")
#fig.savefig("/SSD/home/sofia/gene_trait.png", bbox_inches="tight", dpi=150)

sankey(df_gene_disease_filtered['gene'], df_gene_disease_filtered['disease'],  aspect=10, fontsize=7)
# Get current figure
fig = plt.gcf()
# Set size in inches
fig.set_size_inches(6, 12)
# Set the color of the background to white
fig.set_facecolor("w")
#fig.savefig("/SSD/home/sofia/gene_disease.png", bbox_inches="tight", dpi=150)
#fig.show()

# %%
### FLIP THE IMAGE TO MIRROR IT

# %%
im = imageio.imread('/SSD/home/sofia/gene_trait.png') 
fig, ax1 = plt.subplots(figsize=(6, 12))
ax1.imshow(im[:, ::-1, :])

#fig.savefig("/SSD/home/sofia/gene_trait_reflejada.png", bbox_inches="tight", dpi=150)

# %%
data = sns.load_dataset('iris')
print(data)
# Make the plot
parallel_coordinates(data, 'species', colormap=plt.get_cmap("Set2"))
plt.show()
